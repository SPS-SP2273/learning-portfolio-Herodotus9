# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# ![](https://matplotlib.org/3.1.1/_images/sphx_glr_anatomy_001.png)

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# Code below uses a more powerful ‘dialect’ called the Object Oriented (OO) interface.
#
# This way of talking to Matplotlib gives us a more nuanced control over what is going on by allowing us to manipulate the various axes easily.

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# A figure is the full canvas you use to draw stuff on.
#
# An axis is the individual mathematical axes used for plotting. So, one figure can have multiple axes, as shown below, where we have a (single) figure with four axes.
#
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_exercise-01_solution.png)

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %% [markdown]
# ### pyplot Interface

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
plt.show()

# %% [markdown]
# ### OO Interface

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()
plt.show()
#For the OO interface, start by using subplots() to ask Matplotlib to create a figure and an axis. 
#Matplotlib then gives us a figure (fig) and an axis (ax).

#I can call the variables fig and ax anything I like. 
#But fig and ax are commonly used in documentation. 
#In this example, I need only one column and one row. 
#But, I can also ask for a grid like in the plot right at the top.

# %% [markdown]
# OO looks more comlicated than the pyplot version. But it offers so much freedom for more demanding, complex plots.
#
# pyplot interface: for quick and dirty plots.
#
# OO interface: for more complex plots that demand control and finesse.

# %% [markdown]
# # 3 What is OO ax, really?

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)

ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')

ax[0].legend()
ax[1].legend()
plt.show()
#To get the below plot, we must ask for two rows (nrows=2) and one column (ncols=1). We do this by using subplots()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)

#This gives me two axes so that I can plot in both panes.

# %%
#What is ax? It is a NumPy array

type(ax)
# Out:
# numpy.ndarray

# %%
#What size is ax?
ax.shape
#As expected, ax has two ‘things’.
# Out:
# (2,)

# %%
#What is contained in ax?
type(ax[0])
#This is a Matplotlib axis.
# Out:
# matplotlib.axes._axes.Axes

# %% [markdown]
# # 4 A complete OO example

# %%
#The following is a simple example that creates a nicer, tweaked version of the previous plot.

fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %% [markdown]
# ax[0].fill_between(x, 0, cos_x, alpha=.25)
#
# What does ax.fill_between() do and what do the arguments mean? Is the order important (does x, cos_x, 0 produce the same output?
# - ax.fill_between() fills the area between two horizontal curves.
# - ax.fill_between(x, 0, cos_x, alpha=.25) fills the area between y=0 and y=cos_x along the horizontal axis defined by x
# - The order of y1 and y2 does not matter. Filling from cos_x to 0 and 0 to cos_x is the same, since the area coloured is the same, just starting and ending from opposite locations (Example below)

# %%
#The following is a simple example that creates a nicer, tweaked version of the previous plot.

fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, cos_x, 0, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, sin_x, 0, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %%
#Now, let me take you this code and try to explain what is happening.

fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(3, 10),  #Change the size of the figure by specifying a figure size (figsize).
                       sharex=False)   #Ask that the plots share the -axis using sharex.


ax[0].plot(x, cos_x, label=r'$\cos(x)$')          #Since ax is a NumPy array with two axes, we can index them using 0 and 1.
ax[0].fill_between(x, 0, cos_x, alpha=.25)        #Then just plot to that axis
ax[1].plot(x, sin_x, label=r'$\sin(x)$')          #fill_between() fills the plots. 
ax[1].fill_between(x, 0, sin_x, alpha=.25)        #index the NumPy array to access the axes.

for a in ax:
    a.legend()        #Draw the legends 
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)  #Adds a grid to each plot and set the label.
 

ax[1].set_xlabel('$x$')        #We are sharing the x-axis. So, we only need to label the lowest plot. This has the index 1.

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')  #Adds a super title to the figure (notplot).

fig.tight_layout()  
#tight_layout() asks Matplotlib to make any necessary adjustments to the layout, making the plot looks nice. 
#It would help if you convinced yourself of the utility of tight_layout() by producing the plot with and without it.

# %% [markdown]
# Notice
#
#     The pyplot and OO interfaces don’t use identical function names!
#     For example, pyplot used xlabel() to set the x label, but OO uses set_xlabel().

# %% [markdown]
# # 5 Multiple rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='col')

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %%
#I create a figure and axes using:
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='row')
#How to use ax is impt

# %%
#We know there must be four axes; but how is ax structured? Let’s look at its shape.
ax.shape
# Out:
# (2, 2)

# %%
#So, ax is organised as you see in the figure, as a 2 x 2 array. Each of the axes can be accessed as follows:
ax[0, 0].set_title('Top Left')
ax[0, 1].set_title('Top Right')
ax[1, 0].set_title('Bottom Left')
ax[1, 1].set_title('Bottom Right')
# Out:
# Text(0.5, 1.0, 'Bottom Right')

# %%
#This is a perfectly valid way to use ax. However, when you have to tweak each axis separately,better to use a familiar variable. 
#Example show below

top_left=ax[0, 0]
top_right=ax[0, 1]
bottom_left=ax[1, 0]
bottom_right=ax[1, 1]

# %%
#You can also use:
top_left, top_right, bottom_left, bottom_right = ax.flatten()
#flatten() takes the 2D array and ‘flattens’(dah) it into a 1D array; unpacking takes care of the assignments.

# %%
#Oh, I forgot to show you how I drew the lines. I used the very useful Matplotlib function hlines():
top_left.hlines(y=1, xmin=0, xmax=5)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=5)
bottom_right.hlines(y=4, xmin=0, xmax=5)

# %% [markdown]
# ## 5.1 Sharing axes

# %%
#Notice I have asked Matplotlib to make the plots more compact by sharing the and axes using sharex and sharey.

#Let’s first see what happens if I do not specify how to share.

fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(10, 4)
)
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
#You see that Matplotlib has auto-scaled both axes. 
#In particular, the plots on the left go from 0 to 4, and those on the right go from 0 to 5, as these are the lengths I used for the lines.

# %% [markdown]
# Now, let me specify how to share the axes. I can do this in three ways:
#
# | Option | Result                                       |
# |--------|:----------------------------------------------|
# | True   | Makes all the axes use the same range.       |
# | col    | Use the same range for all the columns.      |
# | row    | Use the same range for all the rows.         |

# %%
#Let’s try the following:

fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(5, 5),
    sharex=True, sharey='row'
)
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
#Notice how all the plots have the same range for the x-axis.

# %%
#However, sharex='col' is more suited for the data we are plotting, so let’s use that instead.
fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(5, 5),
    sharex='col', sharey='row'
)
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()
#By the way, how you decide on the most correct depends on what story you are trying to communicate with your plot.

# %% [markdown]
# ## 5.2 Accessing all axes

# %%
#You will often want to apply changes to all the axes, like in the case of the grid. You can do this by

top_left.grid(alpha=.25)
top_right.grid(alpha=.25)
bottom_left.grid(alpha=.25)
bottom_right.grid(alpha=.25)

#But this is inefficient and requires a lot of work. It is much nicer to use a for loop.

for a in ax.flatten():
    a.grid(alpha=.25)

# %% [markdown]
# # 6 Other useful plots

# %%
#In this section, I will quickly show you some useful plots we can generate with Matplotlib. 
#I will also use a few different plotting styles I commonly use so that you can get a feel for how to change styles.

# %% [markdown]
# ## 6.1 Histograms

# %% [markdown]
# A histogram is a valuable tool for showing distributions of data.
# For this example, I have extracted some actual data from sg.gov related to the mean monthly earnings of graduates from the various universities in Singapore.
#
# https://data.gov.sg/

# %% [markdown]
# ### Data

# %% [markdown]
# Here are the links to my data files:
#
# | Category    | File                                      |
# |-------------|-------------------------------------------|
# | All         | [sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv]      |
# | NUS Only    | [sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv]      |

# %% [markdown]
# ### A quick helper function

# %%
#I will need to read the data from these files several times. So, I will create a function called det_plot_data() that I can call. 
#You must examine the file structure to understand the data and why I am skipping the first line.
    #The first line in the data is basic_monthly_mean, thus we skip the first line.

def get_plot_data():
    data = {}
    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
    data['All'] = np.loadtxt(filename, skiprows=1)

    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
    data['NUS'] = np.loadtxt(filename, skiprows=1)

    return data

# %% [markdown]
# | sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv | basic_monthly_mean |
# |-------------------------------------------------------------|---------------------|
# | 3701                                                        | 2850                |
# | 3053                                                        | 3557                |
# | 3494                                                        | 2952                |
# | 3235                                                        | 3326                |
# | 3091                                                        |                     |
#
# | sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv | basic_monthly_mean |
# |-------------------------------------------------------------|---------------------|
# | 2741                                                        | 3057                |
# | 3098                                                        | 2960                |
# | 3404                                                        | 2740                |
# | 3065                                                        | 3350                |
# | 3933                                                        |                     |

# %% [markdown]
# ### The histogram

# %% [markdown]
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_other_histogram.png)

# %%
plt.style.use('bmh')
data = get_plot_data()

# bins specifies how many bins to split the data
plt.hist([data['All'], data['NUS']], bins=50, label=['All', 'NUS'])
plt.xlabel('Mean of Basic Montly Earning (S$)')
plt.ylabel('Number of Students')
plt.legend()

# %% [markdown]
# ## 6.2 Scatter plots

# %% [markdown]
# Scatter plots are created by putting a marker at an (x,y) point you specify. They are simple yet powerful.
#
# I will be lazy and use the same data as the previous example. But, since I need some values for
# I am going to use range() along with len() to generate a list [0,1,2...] appropriate to the dataset.
#
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_other_scatter.png)

# %%
plt.style.use("seaborn-v0_8-darkgrid")

data = get_plot_data()

for label, numbers in data.items():
    x = range(len(numbers))
    y = numbers
    plt.scatter(x, y, label=label, alpha=.5)

plt.xlabel('Position in the list')
plt.ylabel('Mean of Basic Montly Eraning (S$)')
plt.legend()

# %% [markdown]
# ## 6.3 Bar charts

# %% [markdown]
# I am using some dummy data for a hypothetical class for this example.
# I extract the data and typecast to pass two lists to bar(). Use barh() if you want horizontal bars.
#
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_other_bar.png)

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.bar(majors, numbers)
plt.xlabel('Majors')
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %% [markdown]
# Line #5.    majors = list(student_numbers.keys())
#
# Why is the list function used here? Can't you just use student_numbers.keys() to get all keys?
# - The list function is used to extract the keys or values from the dictionary and convert them into lists.
# - The student_numbers is in the form of a dictionary
# - Using student_numbers.keys() displays a list of all the keys in the dictionary.
# - Using student_numbers.values displays a list of all the values in the dictionary.
# - Instead of extracting the amount of students in each category, it is extracting the key values, which are the 'Life Sciences, Physics, Chemistry and Comp. Biology'
# - The graph will produce the 4 categories on both x and y axes, instead of plot numbers of students against the 4 categories

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.keys())

plt.style.use('ggplot')
plt.bar(majors, numbers)
plt.xlabel('Majors')
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %%
student_numbers = {'Life Sciences': 14, 'Physics': 12, 'Chemistry': 8}
keys = student_numbers.keys()
print(keys)
# Out:
# dict_keys(['Life Sciences', 'Physics', 'Chemistry'])

# %%
student_numbers = {'Life Sciences': 14, 'Physics': 12, 'Chemistry': 8}
values = student_numbers.values()
print(values)
# Out:
# dict_values([14, 12, 8])

# %% [markdown]
# ## 6.4 Pie charts

# %% [markdown]
# ![](https://sps.nus.edu.sg/sp2273/docs/python_basics/07_plotting/__imgs__/plotting_good_other_pie.png)

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys())
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   # How to format the percentages
        startangle=-90                
        )
plt.title('Percentage of each major')
# Out:
# Text(0.5, 1.0, 'Percentage of each major')

# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')

#restart kernel
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 while True:
#       2     print('*', end='')
#       4 #restart kernel
#
# KeyboardInterrupt:

# %%
---------------------------------------------------------------------------
KeyboardInterrupt                         Traceback (most recent call last)
Cell In[1], line 1
----> 1 while True:
      2     print('*', end='')
      4 #restart kernel

KeyboardInterrupt:
# Out:
#   Cell In[2], line 1
#     ---------------------------------------------------------------------------
#                                                                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# print('Hello World')

# %%
print = 'PRINT'

print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 print = 'PRINT'
# ----> 3 print('Hello World')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Perhaps also add a comment on why do you think the error occurred?
#
# After running print = 'PRINT', the second code will be treated by the interpreter as PRINT('Hello World').
#
# As python is sensitive to capitalisation, the code will not work.

# %% [markdown]
# ## Footnotes
